# %% [markdown]
# # **Exercise 1**

# %% [markdown]
# Exercise 1
#
# What are the constants in math module?
#
# answer: 1. math.pi for pi. 2. math.e for logarithm. 3. math.tau for the 2pi
#
# what does math.exp do? or math.pow?
#
# answer: math.exp returns the value of x raised to the power of y the same as math.pow. The only difference is that math.exp accepts 1 parameter and math.pow accepts 2 parameter
#
# How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
#
# answer: Logarithm base 10 -> variable_name = math.log10(x) natural logarithm -> variable_name = math.log(x) note: make sure to import math module

# %% [markdown]
# What are the constants in the math module?
#
# # math.pi
# # math.e
# # math.inf
# # math.nan
# What's does math.exp do? What about math.pow?
#
#
# import math
# print(math.exp(10))
# print(math)
#
# How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
#
#
# import math
#
# print(math.log(10))

# %% [markdown]
# # Exercise **2**

# %%
def sum(num1, num2):
  return num1 + num2

def diff(num1, num2):
  return num1 - num2

def multiply(num1, num2):
  return num1*num2

def divide(num1 , num2):
  if num2 == 0:
    print("error")
  return num1/num2

result_of_sum = sum(5, 3)
result_of_diff = diff(5, 3)
result_of_multiply = multiply(5, 3)
result_of_divide = divide(5, 3)

print("Sum:", result_of_sum)
print("Difference:", result_of_diff)
print("Multiply:", result_of_multiply)
print("Divide:", result_of_divide)
# Out:
# Sum: 8
# Difference: 2
# Multiply: 15
# Divide: 1.6666666666666667
