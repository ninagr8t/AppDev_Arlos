# %%
#exercise1
x = int(input("Enter x: "))
print(x)
if x > 0 :
     print('Above 0')
elif x >  10 :
     print('Above 0 and at most 10')
elif x > 50 :
     print('Above 50')
elif x > 20 :
     print('Above 20')
else :
     print('Something else')

# %%
#exercise 2

hrs = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

pay = hrs * rate
if pay < 40:
    print(pay)
else:
    print("Pay: "+ str(((hrs-40)*(1.5*rate)+ (40 * rate))))
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %%
#Challenge
score = float(input("Enter your score: "))

if score >= 97 and score <= 100:
  grade = 1.0
elif score  >= 93 and score < 97:
  grade = 1.25
elif score >= 89 and score < 93:
  grade = 1.5
elif score >= 85 and score < 89:
  grade = 1.75
elif score >= 81 and score < 85:
  grade = 2.0
elif score >= 77 and score < 81:
  grade = 2.25
elif score >= 74 and score < 77:
  grade = 2.5
elif score >= 0 and score < 74:
  grade = 3.0
else:
  print("Invalid score")
  grade = None

if grade is not None:
  print(f"Grade is {grade}")
