# %%
#exercise1
name = input('Who are you?')
print('Welcome', name)

# %%
#exercise 2
hrs = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

pay = hrs * rate
print("Pay: ", pay)

# %%
#exercise 3
width = 17
result = width//2
print(result, type(result))

width = 17
result = height/3
print(result, type(result))

height = 12.0
result = height/3
print(result, type(result))

result = 1+2*5
print(result, type(result))
# Out:
# Area of the rectangle:  204.0

# %%
#exercise 4
n = int(input("Enter a number: "))

square = n ** 2
print(f"The square of %d %d", n, square)
