# %%
Print('Hello world!')

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print'Hello world!')

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello world!'')

# %%
print('Hellow world!')
# Out:
# Hellow world!

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %%
x = 43
x = X + 1
print(x)

# %%
x = 43
x = x + 1 # the variable 'X' is not declared
print(x)
# Out:
# 44
